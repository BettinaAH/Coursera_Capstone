# %% [markdown]
# # Capstone / Collisions
#
# This Capstone will be used for the Coursera Capstone.

# %%
# import panda
import pandas as pd
import numpy as np

# %%
# Link to csv file to be used
filename = "https://s3.us.cloud-object-storage.appdomain.cloud/cf-courses-data/CognitiveClass/DP0701EN/version-2/Data-Collisions.csv"

# read csv and create dataframe
df_capstone = pd.read_csv(filename)

# head of dataframe
df_capstone.head()
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (33) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    SEVERITYCODE           X          Y  OBJECTID  INCKEY  COLDETKEY REPORTNO  \
# 0             2 -122.323148  47.703140         1    1307       1307  3502005
# 1             1 -122.347294  47.647172         2   52200      52200  2607959
# 2             1 -122.334540  47.607871         3   26700      26700  1482393
# 3             1 -122.334803  47.604803         4    1144       1144  3503937
# 4             2 -122.306426  47.545739         5   17700      17700  1807429
#
#     STATUS      ADDRTYPE   INTKEY  ... ROADCOND                LIGHTCOND  \
# 0  Matched  Intersection  37475.0  ...      Wet                 Daylight
# 1  Matched         Block      NaN  ...      Wet  Dark - Street Lights On
# ...

# %%
df_capstone.groupby("ROADCOND")

# %%
df_capstone["ROADCOND"].value_counts()
# Out:
# Dry               124510
# Wet                47474
# Unknown            15078
# Ice                 1209
# Snow/Slush          1004
# Other                132
# Standing Water       115
# Sand/Mud/Dirt         75
# Oil                   64
# Name: ROADCOND, dtype: int64

# %%
missing_data = df_capstone["ROADCOND"].isnull()
missing_data.head(5)
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: ROADCOND, dtype: bool

# %%
missing_data.value_counts()
# Out:
# False    189661
# True       5012
# Name: ROADCOND, dtype: int64

# %%
df_capstone.shape
# Out:
# (194673, 38)

# %%
df_capstone.values
# Out:
# array([[2, -122.32314840000002, 47.70314032, ..., 0, 0, 'N'],
#        [1, -122.3472943, 47.64717249, ..., 0, 0, 'N'],
#        [1, -122.33453999999999, 47.60787143, ..., 0, 0, 'N'],
#        ...,
#        [2, -122.3066886, 47.68304696, ..., 0, 0, 'N'],
#        [2, -122.35531670000002, 47.67873428, ..., 4308, 0, 'N'],
#        [1, -122.2893597, 47.61101705, ..., 0, 0, 'N']], dtype=object)

# %%
df_capstone.columns
# Out:
# Index(['SEVERITYCODE', 'X', 'Y', 'OBJECTID', 'INCKEY', 'COLDETKEY', 'REPORTNO',
#        'STATUS', 'ADDRTYPE', 'INTKEY', 'LOCATION', 'EXCEPTRSNCODE',
#        'EXCEPTRSNDESC', 'SEVERITYCODE.1', 'SEVERITYDESC', 'COLLISIONTYPE',
#        'PERSONCOUNT', 'PEDCOUNT', 'PEDCYLCOUNT', 'VEHCOUNT', 'INCDATE',
#        'INCDTTM', 'JUNCTIONTYPE', 'SDOT_COLCODE', 'SDOT_COLDESC',
#        'INATTENTIONIND', 'UNDERINFL', 'WEATHER', 'ROADCOND', 'LIGHTCOND',
#        'PEDROWNOTGRNT', 'SDOTCOLNUM', 'SPEEDING', 'ST_COLCODE', 'ST_COLDESC',
#        'SEGLANEKEY', 'CROSSWALKKEY', 'HITPARKEDCAR'],
#       dtype='object')

# %%
df_capstone.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194673 entries, 0 to 194672
# Data columns (total 38 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   SEVERITYCODE    194673 non-null  int64
#  1   X               189339 non-null  float64
#  2   Y               189339 non-null  float64
#  3   OBJECTID        194673 non-null  int64
#  4   INCKEY          194673 non-null  int64
#  5   COLDETKEY       194673 non-null  int64
#  6   REPORTNO        194673 non-null  object
#  7   STATUS          194673 non-null  object
#  8   ADDRTYPE        192747 non-null  object
#  9   INTKEY          65070 non-null   float64
#  10  LOCATION        191996 non-null  object
#  11  EXCEPTRSNCODE   84811 non-null   object
#  12  EXCEPTRSNDESC   5638 non-null    object
#  13  SEVERITYCODE.1  194673 non-null  int64
#  14  SEVERITYDESC    194673 non-null  object
#  15  COLLISIONTYPE   189769 non-null  object
# ...

# %%
# Cleaning the dataframe of unnessecary columns

df_capstone.drop(['EXCEPTRSNDESC', 'EXCEPTRSNCODE', 'SDOTCOLNUM'], axis=1, inplace=True)
df_capstone.head()
# Out:
#    SEVERITYCODE           X          Y  OBJECTID  INCKEY  COLDETKEY REPORTNO  \
# 0             2 -122.323148  47.703140         1    1307       1307  3502005
# 1             1 -122.347294  47.647172         2   52200      52200  2607959
# 2             1 -122.334540  47.607871         3   26700      26700  1482393
# 3             1 -122.334803  47.604803         4    1144       1144  3503937
# 4             2 -122.306426  47.545739         5   17700      17700  1807429
#
#     STATUS      ADDRTYPE   INTKEY  ...   WEATHER  ROADCOND  \
# 0  Matched  Intersection  37475.0  ...  Overcast       Wet
# 1  Matched         Block      NaN  ...   Raining       Wet
# 2  Matched         Block      NaN  ...  Overcast       Dry
# 3  Matched         Block      NaN  ...     Clear       Dry
# 4  Matched  Intersection  34387.0  ...   Raining       Wet
#
#                  LIGHTCOND PEDROWNOTGRNT  SPEEDING  ST_COLCODE  \
# 0                 Daylight           NaN       NaN          10
# ...

# %%
# Checking Values of columns with NaN
df_capstone['PEDROWNOTGRNT'].value_counts()
# Out:
# Y    4667
# Name: PEDROWNOTGRNT, dtype: int64

# %%
# PEDROWNOTGRNT only Y has been entered. Assuming other values to be N
df_capstone['PEDROWNOTGRNT'].fillna("N", inplace=True) 

# transforming it into 0 or 1 instead of yes or now
df_capstone['PEDROWNOTGRNT'].replace('N','0', inplace=True)
df_capstone['PEDROWNOTGRNT'].replace('Y','1', inplace=True)

# transforming the column into integers
df_capstone['PEDROWNOTGRNT'] = df_capstone['PEDROWNOTGRNT'].astype('int64')

# %%
# Checking Values of columns with NaN
df_capstone['SPEEDING'].value_counts()
# Out:
# Y    9333
# Name: SPEEDING, dtype: int64

# %%
# SPEEDING only Y has been entered. Assuming other values to be N
df_capstone['SPEEDING'].fillna("N", inplace=True)

# %%
# Checking Values of columns with NaN
df_capstone['INATTENTIONIND'].value_counts()
# Out:
# Y    29805
# Name: INATTENTIONIND, dtype: int64

# %%
# INATTENTIONIND only Y has been entered. Assuming other values to be N
df_capstone['INATTENTIONIND'].fillna("N", inplace=True)

# %%
df_capstone['INTKEY'].value_counts()
# Out:
# 29973.0    252
# 29933.0    160
# 29913.0    138
# 29549.0    136
# 33512.0    128
#           ...
# 36825.0      1
# 26604.0      1
# 26603.0      1
# 36816.0      1
# 27793.0      1
# Name: INTKEY, Length: 7614, dtype: int64

# %%
# Meaning of INTKEY column can not be identified. There for dropping the column
df_capstone.drop(['INTKEY'], axis=1, inplace=True)

# %%
df_capstone['LOCATION'].value_counts()
# Out:
# BATTERY ST TUNNEL NB BETWEEN ALASKAN WY VI NB AND AURORA AVE N    276
# BATTERY ST TUNNEL SB BETWEEN AURORA AVE N AND ALASKAN WY VI SB    271
# N NORTHGATE WAY BETWEEN MERIDIAN AVE N AND CORLISS AVE N          265
# AURORA AVE N BETWEEN N 117TH PL AND N 125TH ST                    254
# 6TH AVE AND JAMES ST                                              252
#                                                                  ...
# S AUSTIN ST BETWEEN DEAD END AND 35TH AVE S                         1
# NE 57TH ST BETWEEN 8TH AVE NE AND ROOSEVELT WAY NE                  1
# 34TH AVE S BETWEEN CLAREMONT PL S AND S DAKOTA ST                   1
# 34TH AVE BETWEEN E OLIVE ST AND E HOWELL ST                         1
# 6TH AVE S BETWEEN S BRADFORD ST AND S ANDOVER ST                    1
# Name: LOCATION, Length: 24102, dtype: int64

# %%
# cannot sustitute missing data in LOCATION column, filling 0 for the unknown values
df_capstone['LOCATION'].fillna(0, inplace=True)

# %%
df_capstone['UNDERINFL'].value_counts()
# Out:
# N    100274
# 0     80394
# Y      5126
# 1      3995
# Name: UNDERINFL, dtype: int64

# %%
# filling 0 for the unknown values in UNDERINFL column
df_capstone['UNDERINFL'].fillna('0', inplace=True)

# %%
df_capstone['ST_COLCODE'].value_counts()
# Out:
# 32    27612
# 10    23427
# 14    16883
# 32    16809
# 10    11247
#       ...
# 54        1
# 43        1
# 87        1
# 43        1
# 85        1
# Name: ST_COLCODE, Length: 115, dtype: int64

# %%
# column ST_COLCODE: filling 0 for the unknown values
df_capstone['ST_COLCODE'].fillna(0, inplace=True)

# %%
df_capstone_NaN = df_capstone.isnull().sum()
print (df_capstone_NaN)
# Out:
# SEVERITYCODE         0
# X                 5334
# Y                 5334
# OBJECTID             0
# INCKEY               0
# COLDETKEY            0
# REPORTNO             0
# STATUS               0
# ADDRTYPE          1926
# LOCATION             0
# SEVERITYCODE.1       0
# SEVERITYDESC         0
# COLLISIONTYPE     4904
# PERSONCOUNT          0
# PEDCOUNT             0
# PEDCYLCOUNT          0
# VEHCOUNT             0
# INCDATE              0
# INCDTTM              0
# JUNCTIONTYPE      6329
# SDOT_COLCODE         0
# SDOT_COLDESC         0
# INATTENTIONIND       0
# UNDERINFL            0
# WEATHER           5081
# ROADCOND          5012
# LIGHTCOND         5170
# PEDROWNOTGRNT        0
# SPEEDING             0
# ST_COLCODE           0
# ST_COLDESC        4904
# SEGLANEKEY           0
# CROSSWALKKEY         0
# HITPARKEDCAR         0
# dtype: int64

# %%
# Checking Values of column Junctiontype
df_capstone['JUNCTIONTYPE'].value_counts()
# Out:
# Mid-Block (not related to intersection)              89800
# At Intersection (intersection related)               62810
# Mid-Block (but intersection related)                 22790
# Driveway Junction                                    10671
# At Intersection (but not related to intersection)     2098
# Ramp Junction                                          166
# Unknown                                                  9
# Name: JUNCTIONTYPE, dtype: int64

# %%
# Junctiontype column: Assuming NaN values to be Unknown
df_capstone['JUNCTIONTYPE'].fillna("Unknown", inplace=True)

# %%
df_capstone_NaN = df_capstone.isnull().sum()
print (df_capstone_NaN)
# Out:
# SEVERITYCODE         0
# X                 5334
# Y                 5334
# OBJECTID             0
# INCKEY               0
# COLDETKEY            0
# REPORTNO             0
# STATUS               0
# ADDRTYPE          1926
# LOCATION             0
# SEVERITYCODE.1       0
# SEVERITYDESC         0
# COLLISIONTYPE     4904
# PERSONCOUNT          0
# PEDCOUNT             0
# PEDCYLCOUNT          0
# VEHCOUNT             0
# INCDATE              0
# INCDTTM              0
# JUNCTIONTYPE         0
# SDOT_COLCODE         0
# SDOT_COLDESC         0
# INATTENTIONIND       0
# UNDERINFL            0
# WEATHER           5081
# ROADCOND          5012
# LIGHTCOND         5170
# PEDROWNOTGRNT        0
# SPEEDING             0
# ST_COLCODE           0
# ST_COLDESC        4904
# SEGLANEKEY           0
# CROSSWALKKEY         0
# HITPARKEDCAR         0
# dtype: int64

# %%
# Checking Values of column Collisiontype
df_capstone['COLLISIONTYPE'].value_counts()
# Out:
# Parked Car    47987
# Angles        34674
# Rear Ended    34090
# Other         23703
# Sideswipe     18609
# Left Turn     13703
# Pedestrian     6608
# Cycles         5415
# Right Turn     2956
# Head On        2024
# Name: COLLISIONTYPE, dtype: int64

# %%
# Collisiontype column: Assuming NaN values to be Unknown
df_capstone['COLLISIONTYPE'].fillna("Unknown", inplace=True)

# %%
# Checking Values of column Weather
df_capstone['WEATHER'].value_counts()
# Out:
# Clear                       111135
# Raining                      33145
# Overcast                     27714
# Unknown                      15091
# Snowing                        907
# Other                          832
# Fog/Smog/Smoke                 569
# Sleet/Hail/Freezing Rain       113
# Blowing Sand/Dirt               56
# Severe Crosswind                25
# Partly Cloudy                    5
# Name: WEATHER, dtype: int64

# %%
# Weather column: Assuming NaN values to be Unknown
df_capstone['WEATHER'].fillna("Unknown", inplace=True)

# %%
# Checking Values of column Roadconditions
df_capstone['ROADCOND'].value_counts()
# Out:
# Dry               124510
# Wet                47474
# Unknown            15078
# Ice                 1209
# Snow/Slush          1004
# Other                132
# Standing Water       115
# Sand/Mud/Dirt         75
# Oil                   64
# Name: ROADCOND, dtype: int64

# %%
# Roadcondition column: Assuming NaN values to be Unknown
df_capstone['ROADCOND'].fillna("Unknown", inplace=True)

# %%
# Checking Values of column Lightconditions
df_capstone['LIGHTCOND'].value_counts()
# Out:
# Daylight                    116137
# Dark - Street Lights On      48507
# Unknown                      13473
# Dusk                          5902
# Dawn                          2502
# Dark - No Street Lights       1537
# Dark - Street Lights Off      1199
# Other                          235
# Dark - Unknown Lighting         11
# Name: LIGHTCOND, dtype: int64

# %%
# Lightcondition column: Assuming NaN values to be Unknown
df_capstone['LIGHTCOND'].fillna("Unknown", inplace=True)

# %%
# Checking Values of column ST_COLDESC
df_capstone['ST_COLDESC'].value_counts()
# Out:
# One parked--one moving                                                 44421
# Entering at angle                                                      34674
# From same direction - both going straight - one stopped - rear-end     25771
# Fixed object                                                           13554
# From same direction - both going straight - both moving - sideswipe    12777
#                                                                        ...
# Railway Vehicle Strikes Pedalcyclist                                       2
# Vehicle Strikes All Other Non-Domestic Animal                              2
# Vehicle Strikes Deer                                                       1
# Non-domestic animal (deer, bear, elk, etc)                                 1
# Vehicle Hits State Road or Construction Machinery                          1
# Name: ST_COLDESC, Length: 62, dtype: int64

# %%
# ST_COLDESC column: Assuming NaN values to be Unknown
df_capstone['ST_COLDESC'].fillna("Unknown", inplace=True)

# %%
df_capstone_NaN = df_capstone.isnull().sum()
print (df_capstone_NaN)
# Out:
# SEVERITYCODE         0
# X                 5334
# Y                 5334
# OBJECTID             0
# INCKEY               0
# COLDETKEY            0
# REPORTNO             0
# STATUS               0
# ADDRTYPE          1926
# LOCATION             0
# SEVERITYCODE.1       0
# SEVERITYDESC         0
# COLLISIONTYPE        0
# PERSONCOUNT          0
# PEDCOUNT             0
# PEDCYLCOUNT          0
# VEHCOUNT             0
# INCDATE              0
# INCDTTM              0
# JUNCTIONTYPE         0
# SDOT_COLCODE         0
# SDOT_COLDESC         0
# INATTENTIONIND       0
# UNDERINFL            0
# WEATHER              0
# ROADCOND             0
# LIGHTCOND            0
# PEDROWNOTGRNT        0
# SPEEDING             0
# ST_COLCODE           0
# ST_COLDESC           0
# SEGLANEKEY           0
# CROSSWALKKEY         0
# HITPARKEDCAR         0
# dtype: int64

# %% [markdown]
# # Data now cleaned of NaNs
# The rest of the NaNs should not do any harm, as the columns are very likely not be used in this analysis.
#
# # Next step: transformation of data to be easier for analysis by One Hot Encoding
# Therefor I will put the different conditions of the columns like "weather" or "collisiontype" into different columns.

# %%
df_an = df_capstone

# %%
#drop more unnecessary columns
df_an = df_an.drop(['OBJECTID','SEVERITYDESC','INCDATE' , 'INCDTTM','INCKEY', 'COLDETKEY', 'REPORTNO', 'LOCATION','STATUS', 'SEGLANEKEY', 'CROSSWALKKEY', 'SDOT_COLDESC','ST_COLDESC', 'HITPARKEDCAR','X','Y','SEVERITYCODE.1'],axis=1)

# %%
# splitting the column of weather
df_an[pd.get_dummies(df_an['WEATHER']).columns] = pd.get_dummies(df_an['WEATHER'])
df_an.drop(['WEATHER'], axis=1, inplace=True)

# splitting the column of collisiontype
df_an[pd.get_dummies(df_an['COLLISIONTYPE']).columns] = pd.get_dummies(df_an['COLLISIONTYPE'])
df_an.drop(['COLLISIONTYPE'], axis=1, inplace=True)

# splitting the column of Addresstype 
df_an[pd.get_dummies(df_an['ADDRTYPE']).columns] = pd.get_dummies(df_an['ADDRTYPE'])
df_an.drop(['ADDRTYPE'], axis=1, inplace=True)

# splitting the column of junctiontype
df_an[pd.get_dummies(df_an['JUNCTIONTYPE']).columns] = pd.get_dummies(df_an['JUNCTIONTYPE'])
df_an.drop(['JUNCTIONTYPE'], axis=1, inplace=True)

# splitting the column of roadconditions
df_an[pd.get_dummies(df_an['ROADCOND']).columns] = pd.get_dummies(df_an['ROADCOND'])
df_an.drop(['ROADCOND'], axis=1, inplace=True)

# splitting the column of lightconditions
df_an[pd.get_dummies(df_an['LIGHTCOND']).columns] = pd.get_dummies(df_an['LIGHTCOND'])
df_an.drop(['LIGHTCOND'], axis=1, inplace=True)

df_an.head()
# Out:
#    SEVERITYCODE  PERSONCOUNT  PEDCOUNT  PEDCYLCOUNT  VEHCOUNT  SDOT_COLCODE  \
# 0             2            2         0            0         2            11
# 1             1            2         0            0         2            16
# 2             1            4         0            0         3            14
# 3             1            3         0            0         3            11
# 4             2            2         0            0         2            11
#
#   INATTENTIONIND UNDERINFL  PEDROWNOTGRNT SPEEDING  ... Snow/Slush  \
# 0              N         N              0        N  ...          0
# 1              N         0              0        N  ...          0
# 2              N         0              0        N  ...          0
# 3              N         N              0        N  ...          0
# 4              N         0              0        N  ...          0
#
#    Standing Water  Wet  Dark - No Street Lights  Dark - Street Lights Off  \
# ...

# %%
# In the column Inattiontion there seems to be two ways of labels (yes (Y) / no (N) and 0 and 1), so I will align that and only make it 0 or 1

df_an['INATTENTIONIND'] = df_an['INATTENTIONIND'].map({'Y': '1', 'N': '0'})

# %%
df_an['INATTENTIONIND'] = df_an['INATTENTIONIND'] .astype('int64')

# %% [markdown]
# # Starting with modeling phase where various algorithms and methods are tried out

# %%
# looking at the correlation between the different attributes

df_an.corr().style.background_gradient(cmap='coolwarm').format("{:.2f}")
# Out:
# <style  type="text/css" >
#     #T_77eb41cc_e6f2_11ea_9f01_96d97a17fa9brow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_77eb41cc_e6f2_11ea_9f01_96d97a17fa9brow0_col1 {
#             background-color:  #85a8fc;
#             color:  #000000;
#         }    #T_77eb41cc_e6f2_11ea_9f01_96d97a17fa9brow0_col2 {
#             background-color:  #c1d4f4;
#             color:  #000000;
#         }    #T_77eb41cc_e6f2_11ea_9f01_96d97a17fa9brow0_col3 {
#             background-color:  #b7cff9;
#             color:  #000000;
#         }    #T_77eb41cc_e6f2_11ea_9f01_96d97a17fa9brow0_col4 {
#             background-color:  #85a8fc;
#             color:  #000000;
#         }    #T_77eb41cc_e6f2_11ea_9f01_96d97a17fa9brow0_col5 {
#             background-color:  #c1d4f4;
#             color:  #000000;
#         }    #T_77eb41cc_e6f2_11ea_9f01_96d97a17fa9brow0_col6 {
#             background-color:  #6485ec;
#             color:  #000000;
# ...

# %% [markdown]
# ## What are we learning from the correlation table?
# It is acutally really suprising, that there are so little correlation with the **severity of the accident**. All attributes show a very low correlation.
#
# The ones with a little higher correlation (corr > 0.2) are accidents at intersections or accistents that involved parked cars, pedestrians or cyclists. Which would mean if you as a driver approach a intersection, parked cars, pedestrians or cyclists: be more careful. Also the ones responsible for designing the intersections, pedestrian crossings, cycle lanes and parking lots should be mindful in design them.
#
# But when I started this projects, I assumpted that bad weather would be a big influence of probability of an accident.
# It does not look like it when looking at this big data set of Seattle.

# %% [markdown]
# # Looking deeper into the ones that are slightly more correlated

# %%
import sklearn.model_selection as model_selection
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier
from sklearn import svm
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

# %%
# setting up for training and train/test split

df_modeling = df_an[['SEVERITYCODE','PERSONCOUNT','PEDCOUNT','PEDCYLCOUNT','Parked Car','PEDROWNOTGRNT','Intersection', 'Cycles', 'Pedestrian', 'At Intersection (intersection related)']]
X = df_modeling.drop(['SEVERITYCODE'],axis=1)
y = df_modeling['SEVERITYCODE']
X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, train_size=0.8,test_size=0.2)

print("done")
# Out:
# done

# %%
# Looking at the Logistic Regression

lr = LogisticRegression()
lr.fit(X_train,y_train)
yhat_lr=lr.predict(X_test)

print("done")
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# done

# %%
# looking into Support Vector Machine

clf = svm.SVC(kernel = "linear")
clf.fit(X_train, y_train)
yhat_svm = clf.predict(X_test)
print("done")
# Out:
# done

# %%
# looking at the Decision Tree

dt = DecisionTreeClassifier(criterion = "entropy", max_depth=10)
dt.fit(X_train, y_train)
yhat_dt = dt.predict(X_test)

print("done")
# Out:
# done

# %%
# looking into Random Forest Classifier

m = RandomForestClassifier(n_estimators=100, criterion="entropy")
m.fit(X_train, y_train)
yhat_rfc = m.predict(X_test)

print("done")
# Out:
# done

# %%
# Overview of different scores from the modeling

# %%
from sklearn.metrics import f1_score, precision_score, recall_score
f1lr = f1_score(y_test, yhat_lr)
f1dt = f1_score(y_test, yhat_dt)
f1rf = f1_score(y_test, yhat_rfc)
f1svm = f1_score(y_test, yhat_svm)


acclr = accuracy_score(y_test, yhat_lr)
accdt = accuracy_score(y_test, yhat_dt)
accrf = accuracy_score(y_test, yhat_rfc)
accsvm = accuracy_score(y_test, yhat_svm)


plr = precision_score(y_test, yhat_lr)
pdt = precision_score(y_test, yhat_dt)
prf = precision_score(y_test, yhat_rfc)
psvm = precision_score(y_test, yhat_svm)

rlr = recall_score(y_test, yhat_lr)
rdt = recall_score(y_test, yhat_dt)
rrf = recall_score(y_test, yhat_rfc)
rsvm = recall_score(y_test, yhat_svm)


results = [['Model', 'Accuracy score', 'F1 score', 'Precision','Recall'],['Logistic Regression', acclr, f1lr, plr, rlr],['Decision Tree',accdt, f1dt,pdt,rdt],['Random Forest',accrf,f1rf,prf,rrf],['Support Vector Machine', accsvm, f1svm, psvm, rsvm]]
results = pd.DataFrame(results)       
print(results)
# Out:
#                         0               1         2          3         4
# 0                   Model  Accuracy score  F1 score  Precision    Recall
# 1     Logistic Regression        0.751637  0.845567   0.749243  0.970311
# 2           Decision Tree        0.752023   0.84704    0.74594  0.979841
# 3           Random Forest        0.751946  0.847004   0.745864  0.979878
# 4  Support Vector Machine         0.75061   0.84761   0.741155  0.989774

# %% [markdown]
# # One more look into the road and weather conditions
#
# what if I add up the bad road and weather conditions to "good" and "bad". As it might not matter if the road is icy or wet, it both might increase the propability of an accident.
#
# That's why I will adjust the data so that there are only two conditions good = 0 and bad = 1

# %%
df_01 = df_capstone

# %%
df_01.shape
# Out:
# (194673, 34)

# %% [markdown]
# ## deleting rows where the Roadcondition is marked as "other" or "unknown" or "oil"

# %%
# replace "Other" and "Unknown" to NaN
df_01.replace("Other", np.nan, inplace = True)
df_01.replace("Unknown", np.nan, inplace = True)
df_01.replace("Oil", np.nan, inplace = True) # shortcut to delete also Roadconditions with "oil", as they are not weather dependent

# drop whole row with NaN in "ROADCOND" column
df_01.dropna(subset=["ROADCOND"], axis=0, inplace=True)

# drop whole row with NaN in "WEATHER" column
df_01.dropna(subset=["WEATHER"], axis=0, inplace=True)


df_01.shape
# Out:
# (172546, 34)

# %%
# Replacing ROADCOND values with 0 for good/fine weather and 1 for bad weather
df_01['ROADCOND'].replace(to_replace=['Wet','Dry','Snow/Slush','Ice','Sand/Mud/Dirt','Standing Water'], value = ['1','0','1','1','1','1'], inplace=True)

# %%
# Replacing Weather values with 0 for good/fine weather and 1 for bad weather
df_01['WEATHER'].replace(to_replace=['Clear','Raining','Overcast','Snowing','Fog/Smog/Smoke','Sleet/Hail/Freezing Rain','Blowing Sand/Dirt','Severe Crosswind','Partly Cloudy'], value = ['0','1','0','1','1','1','1','1','0'], inplace=True)

# %%
df_SRW = df_01[['SEVERITYCODE','ROADCOND','WEATHER']] # SRW stands for Serveritycode Roadconditions Weather
df_SRW.head()
# Out:
#    SEVERITYCODE ROADCOND WEATHER
# 0             2        1       0
# 1             1        1       1
# 2             1        0       0
# 3             1        0       0
# 4             2        1       1

# %% [markdown]
# ## Looking at Correlation of Severitycode and the grouped bad/fine weather columns Roadcondition and Weather

# %%
# looking at the correlation between the different attributes

df_SRW["ROADCOND"]=df_SRW["ROADCOND"].astype(int, copy=True)
df_SRW["WEATHER"]=df_SRW["WEATHER"].astype(int, copy=True)
df_SRW.dtypes
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# SEVERITYCODE    int64
# ROADCOND        int64
# WEATHER         int64
# dtype: object

# %%
df_SRW.corr()
# Out:
#               SEVERITYCODE  ROADCOND   WEATHER
# SEVERITYCODE      1.000000  0.005073  0.009146
# ROADCOND          0.005073  1.000000  0.760825
# WEATHER           0.009146  0.760825  1.000000

# %% [markdown]
# ### Result from looking at grouped bad and fine weather
#
# Also from this analysis I can only see that there is a very low correlation to the severity.
#
# Therefor it does not make sense to warn drivers especially because of bad road or weather conditions as their impact on the probability of an accident is low.
